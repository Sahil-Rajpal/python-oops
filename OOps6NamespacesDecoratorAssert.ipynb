# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahil-Rajpal/python-oops/blob/main/OOps6NamespacesDecoratorAssert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Namespaces
#
# A namespace is a space that holds names(identifiers).Programmatically speaking, namespaces are dictionary of identifiers(keys) and their objects(values)
#
# There are 4 types of namespaces:
# - Builtin Namespace
# - Global Namespace
# - Enclosing Namespace
# - Local Namespace

# %% [markdown]
# ### Scope and LEGB Rule
#
# A scope is a textual region of a Python program where a namespace is directly accessible.
#
# The interpreter searches for a name from the inside out, looking in the local, enclosing, global, and finally the built-in scope. If the interpreter doesn’t find the name in any of these locations, then Python raises a NameError exception.

# %% [markdown]
# ### Local and Global

# %%
# local and global

a = 2 # global var

def temp():

  b = 3  # local var
  print(b)

temp()
print(a)
# Out:
# 3
# 2

# %%
# local and global -> same name
a = 2

def temp():
  # local var
  a = 3

  print(b)

temp()
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3171/3207942875.py in <cell line: 0>()
#       8   print(b)
#       9
# ---> 10 temp()
#      11 print(a)
#
# /tmp/ipykernel_3171/3207942875.py in temp()
#       6   a = 3
#       7
# ----> 8   print(b)
#       9
#      10 temp()
#
# NameError: name 'b' is not defined

# %%
# local and global -> local does not have but global has
a = 2

def temp():
  # local var
  print(a)

temp()
print(a)
# Out:
# 2
# 2

# %%
# local and global -> editing global
a = 2

def temp():
  # local var
  a += 1 # we can changes global scope var but can print
  print(a)

temp()
print(a)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_3171/2673954895.py in <cell line: 0>()
#       7   print(a)
#       8
# ----> 9 temp()
#      10 print(a)
#
# /tmp/ipykernel_3171/2673954895.py in temp()
#       4 def temp():
#       5   # local var
# ----> 6   a += 1 # we can changes global scope var but can print
#       7   print(a)
#       8
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
## aise global me change nahi kar sakte hai but global keyword use karke kar sakte hai

# %%
a = 2

def temp():
  # local var
  global a # we are showing that we have to chnage in global
  a += 1
  print(a)

temp()
print(a)
# Out:
# 3
# 3

# %%
# local and global -> global created inside local
def temp():
  # local var
  global a
  a = 1
  print(a)

temp()
print(a)
# Out:
# 1
# 1

# %% [markdown]
# ### yaha par global namespace a bana , local me nahi
#
# - local se global me var create kar sakte hai

# %%
# local and global -> function parameter is local
def temp(z):
  # local var
  print(z)

a = 5
temp(5)
print(a)
print(z) # global me show nahi karega
# Out:
# 5
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3171/2737723783.py in <cell line: 0>()
#       7 temp(5)
#       8 print(a)
# ----> 9 print(z) # global me show nahi karega
#
# NameError: name 'z' is not defined

# %% [markdown]
# ### yaha par z local var hai

# %% [markdown]
# ### Built-in Scope

# %%
# built-in scope
import builtins
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# how to see all the built-ins

# %%
# renaming built-ins
L = [1,2,3]
print(max(L))
def max():
  print('hello')

print(max(L))

# yaha par humko global me hi max mil gaya so builin me chack nahi hua . A/C to LEGB rule
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3171/2003526838.py in <cell line: 0>()
#       1 # renaming built-ins
#       2 L = [1,2,3]
# ----> 3 print(max(L))
#       4 # def max():
#       5 #   print('hello')
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %% [markdown]
# ### Enclosing Scope

# %%
# Enclosing scope
def outer():
 #  a=3 # enclosing
  def inner():  # LEGB rule
   # a=4 # local
    print(a)
  inner()
  print('outer function')

a=1 # global (aur agar yaha bhi nahi hua toh builtin me milega)
outer()
print('main program')
# Out:
# 1
# outer function
# main program

# %%
# nonlocal keyword
def outer():
  a = 1
  def inner():
    nonlocal a # nonlocal ke help se hum enclosing me change kar rahe hai
    a += 1
    print('inner',a)
  inner()
  print('outer',a)


outer()
print('main program')
# Out:
# inner 2
# outer 2
# main program

# %% [markdown]
# ### Decorators
#
# A decorator in python is a function that receives another function as input and adds some functionality(decoration) to and it and returns it.
#
# This can happen only because python functions are 1st class citizens.
#
# There are 2 types of decorators available in python
# - `Built in decorators` like `@staticmethod`, `@classmethod`, `@abstractmethod` and `@property` etc
# - `User defined decorators` that we programmers can create according to our needs

# %%
# Python are 1st class function

def modify(func,num):
  return func(num)

def square(num):
  return num**2

modify(square,2)
# Out:
# 4

# %%
# simple example

def my_decorator(func): # yaha par input me ek dusra function hai
  def wrapper():
    print('***********************')
    func()
    print('***********************')
  return wrapper

def hello():
  print('hello')

def display():
  print('hello nitish')

a = my_decorator(hello)
a()

b = my_decorator(display)
b()
# Out:
# ***********************
# hello
# ***********************
# ***********************
# hello nitish
# ***********************

# %%
# more functions

# %%
# how this works -> closure?

# %%
# python tutor

# %%
# Better syntax?
# simple example

def my_decorator(func):
  def wrapper():
    print('***********************')
    func()
    print('***********************')
  return wrapper

@my_decorator  # aise likhte hai decroator ko simple syntax mai
def hello():
  print('hello')

hello()
# Out:
# ***********************
# hello
# ***********************

# %%
# anything meaningful?
import time

def timer(func):
  def wrapper(*args):
    start = time.time()
    func(*args)
    print('time taken by',func.__name__,time.time()-start,'secs')
  return wrapper

@timer
def hello():
  print('hello wolrd')
  time.sleep(2)

@timer
def square(num):
  time.sleep(1)
  print(num**2)

@timer
def power(a,b):
  print(a**b)

hello()
square(2)
power(2,3)
# Out:
# hello wolrd
# time taken by hello 2.00020170211792 secs
# 4
# time taken by square 1.0002398490905762 secs
# 8
# time taken by power 1.0251998901367188e-05 secs

# %%
# A big problem

# %%
# One last example -> decorators with arguments

# %%
@checkdt(int)
def square(num):
  print(num**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_541/298280272.py in <cell line: 0>()
# ----> 1 @checkdt(int)
#       2 def square(num):
#       3   print(num**2)
#
# NameError: name 'checkdt' is not defined

# %%
def sanity_check(data_type):
  def outer_wrapper(func):
    def inner_wrapper(*args):
      if type(*args) == data_type:
        func(*args)
      else:
        raise TypeError('Ye datatype nai chalega')
    return inner_wrapper
  return outer_wrapper

@sanity_check(int)
def square(num):
  print(num**2)

@sanity_check(str)
def greet(name):
  print('hello',name)

square(2)
# Out:
# 4
