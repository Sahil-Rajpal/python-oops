# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahil-Rajpal/python-oops/blob/main/OOps2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Write OOP classes to handle the following scenarios:
#
# - A user can create and view 2D coordinates
# - A user can find out the distance between 2 coordinates
# - A user can find find the distance of a coordinate from origin
# - A user can check if a point lies on a given line
# - A user can find the distance between a given 2D point and a given line

# %%
from re import A
class Points:
  def __init__(self,x,y):  # self her is the current object
    self.x_cod=x
    self.y_cod=y

# for printing the point --> magic methods using str
  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)


  def euclidean_distance(self,other):
    return ((self.x_cod-other.x_cod)**2+(self.y_cod-other.y_cod)**2)**0.5




  def distance_from_origin(self):
    return self.euclidean_distance(Points(0,0))







class Line:
  def __init__(self,A,B,C):
    self.A=A
    self.B=B
    self.C=C


  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)

  def point_on_line(self,Points):
    if self.A*Points.x_cod + self.B*Points.y_cod + self.C ==0:
      return 'Lies on the line'
    else:
      return 'Does not lie on the line'


  def shortest_distance(self,Points):
    return abs(self.A*Points.x_cod + self.B*Points.y_cod + self.C)/(self.A**2+self.B**2)**0.5

# %%
p1=Points(3,4)
p2=Points(0,0)
# <x,y>
print(p1)
# Out:
# <3,4>

# %%
p1.euclidean_distance(p2)
# Out:
# 5.0

# %%
p1.distance_from_origin()
# Out:
# 5.0

# %%
l1=Line(3,3,3)
print(l1)
# Out:
# 3x + 3y + 3 = 0

# %%
p1=Points(1,1)
print(p1)
# Out:
# <1,1>

# %%
l1.point_on_line(p1)
# Out:
# 'Does not lie on the line'

# %%
l1.shortest_distance(p1)
# Out:
# 2.121320343559643

# %%
### How objects access attributes

# %% [markdown]
# ### How objects access attributes

# %%
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'india':
      print('Namaste',self.name)
    else:
      print('Hello',self.name)

# %%
# how to access attributes  --> matlab data ko kaise access karta hai

p=Person('nitish','india')

# %%
p.country
# Out:
# 'india'

# %%
p.name
# Out:
# 'nitish'

# %%
p.greet()
# Out:
# Namaste nitish

# %%
# what if i try to access non existent attributes
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_310/3903310099.py in <cell line: 0>()
#       1 # what if i try to access non existent attributes
# ----> 2 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %%
### Attribute creation from outside of the class

# %%
p.gender='male'

# %%
p.gender

# %%
# class ke bahar se class ke andar ek attributes create kar diya

# %%
### Reference Variables

- Reference variables hold the objects
- We can create objects without reference variable as well
- An object can have multiple reference variables
- Assigning a new reference variable to an existing object does not create a new object
# Out:
#   File "/tmp/ipykernel_310/2568255984.py", line 3
#     - Reference variables hold the objects
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Reference Variables
#
# - Reference variables hold the objects
# - We can create objects without reference variable as well
# - An object can have multiple reference variables
# - Assigning a new reference variable to an existing object does not create a new object

# %%
# object without a reference
class Person:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

p = Person()  # here p is not the object.p is the variable which has memory address of the object
q = p

# %%
Person()

# %%
print(id(p))
print(id(q))
# Out:
# 140610306479152
# 140610306479152

# %%
# change attribute value with the help of 2nd object

# %%
print(p.name)
print(q.name)
# Out:
# nitish
# nitish

# %%
q.name='sahil'
print(p.name)
print(p.name)
# Out:
# sahil
# sahil

# %% [markdown]
# ### Pass by reference

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# ouside the class -->  hence it is a function
def greet(Person):
  print('Hi my name is',Person.name,'and I am a',Person.gender)
  p1=Person('ankit','male')
  return p1

p=Person('nitish','male')

# we can pass class object as input to the function
# and a  fuction can return the output as object.
x=greet(p)
print(x.name)
print(x.gender)
# Out:
# Hi my name is nitish and I am a male
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_310/2844098607.py in <cell line: 0>()
#      15 # we can pass class object as input to the function
#      16 # and a  fuction can return the output as object.
# ---> 17 x=greet(p)
#      18 print(x.name)
#      19 print(x.gender)
#
# /tmp/ipykernel_310/2844098607.py in greet(Person)
#       8 def greet(Person):
#       9   print('Hi my name is',Person.name,'and I am a',Person.gender)
# ---> 10   p1=Person('ankit','male')
#      11   return p1
#      12
#
# TypeError: 'Person' object is not callable

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print(id(person))
  person.name = 'ankit'
  print(person.name)

p = Person('nitish','male')
print(id(p))
greet(p)
print(p.name)
# Out:
# 140610306477280
# 140610306477280
# ankit
# ankit

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  person.name = 'ankit'
  return person

p = Person('nitish','male')
print(id(p))
p1 = greet(p)
print(id(p1))
# Out:
# 140610306476752
# 140610306476752

# %%
### Encapsulation

# %%
# instance var -> python tutor
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

p1 = Person('nitish','india')
p2 = Person('steve','australia')

# %%
p2.name
# Out:
# 'steve'

# %%
class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0  # attribute ke aage __ lagane se private ho jata hai
    #self.menu()


# getter
  def get_balance(self):
    return self.__balance

# setter
  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 140610306479248

# %%
obj.get_balance()
# Out:
# 1000

# %%
obj.set_balance(1000)

# %%
obj.withdraw()
# Out:
# enter the pin1234
# sale chor

# %%
obj.

# %% [markdown]
# ### Collection of objects

# %%
# list of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

L = [p1,p2,p3]
print(L)
for i in L:
  print(i.name,i.gender)
# Out:
# [<__main__.Person object at 0x7fe2635e9c10>, <__main__.Person object at 0x7fe2635e9f40>, <__main__.Person object at 0x7fe262333260>]
# nitish male
# ankit male
# ankita female

# %%
# dict of objects
# list of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

d = {'p1':p1,'p2':p2,'p3':p3}

for i in d:
  print(d[i].gender)
# Out:
# male
# male
# female

# %%
### Static Variables(Vs Instance variables)

# %% [markdown]
# ### Static Variables(Vs Instance variables)

# %%
# need for static vars

# %%
class Atm:

  __counter = 1

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.__counter
    Atm.__counter = Atm.__counter + 1
    #self.menu()

  # utility functions
  @staticmethod
  def get_counter():
    return Atm.__counter


  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()
# Out:
# 140610286861488

# %%
Atm.get_counter()
# Out:
# 2

# %%
c3 = Atm()
# Out:
# 140610286854384

# %%
c3.cid
# Out:
# 2

# %%
Atm.counter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_310/2466974913.py in <cell line: 0>()
# ----> 1 Atm.counter
#
# AttributeError: type object 'Atm' has no attribute 'counter'
